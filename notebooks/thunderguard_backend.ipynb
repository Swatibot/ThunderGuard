# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import requests

print("All ThunderGuard packages are working!")
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Scikit-learn:", sklearn.__version__)
# Out:
# All ThunderGuard packages are working!
# Pandas: 3.0.0
# NumPy: 2.2.3
# Scikit-learn: 1.9.0

# %%
print("ThunderGuard Backend Started")
# Out:
# ThunderGuard Backend Started
