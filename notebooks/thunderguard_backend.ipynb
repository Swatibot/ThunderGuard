# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

RAW_DATA_DIR = PROJECT_ROOT / "data" / "raw"
PROCESSED_DATA_DIR = PROJECT_ROOT / "data" / "processed"
MODEL_DIR = PROJECT_ROOT / "models"

print("Project:", PROJECT_ROOT)
print("Raw data:", RAW_DATA_DIR)
print("Processed data:", PROCESSED_DATA_DIR)
print("Models:", MODEL_DIR)
# Out:
# Project: c:\Users\Lenovo\Desktop\Innovatrix\ThunderGuard
# Raw data: c:\Users\Lenovo\Desktop\Innovatrix\ThunderGuard\data\raw
# Processed data: c:\Users\Lenovo\Desktop\Innovatrix\ThunderGuard\data\processed
# Models: c:\Users\Lenovo\Desktop\Innovatrix\ThunderGuard\models

# %%
import requests

url = "https://api.imd.gov.in/api/v1/districtnowcast"

response = requests.get(url)

print("Status Code:", response.status_code)
print(response.text[:1000])
# Out:
# Status Code: 401
# {"error":"API key missing"}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import requests

print("All ThunderGuard packages are working!")
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Scikit-learn:", sklearn.__version__)
# Out:
# All ThunderGuard packages are working!
# Pandas: 3.0.0
# NumPy: 2.2.3
# Scikit-learn: 1.9.0

# %%
print("ThunderGuard Backend Started")
# Out:
# ThunderGuard Backend Started
